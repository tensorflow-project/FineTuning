# %% [markdown]
# <a href="https://colab.research.google.com/github/tensorflow-project/FineTuning/blob/main/deleteMe/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt

drive.mount("/content/drive")
path1 = '/content/drive/MyDrive/data tensorboard/epoch_accuracy20230321-104734_train.csv'
path2 = '/content/drive/MyDrive/data tensorboard/epoch_accuracy20230321-104734_validation.csv'
path3 = '/content/drive/MyDrive/data tensorboard/epoch_loss20230321-104734_train.csv'
path4 = '/content/drive/MyDrive/data tensorboard/epoch_loss20230321-104734_validation.csv'
import csv
import matplotlib.pyplot as plt
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib as mpl
mpl.use('ps')

# Load the CSV file using NumPy
data1 = np.loadtxt(path1, delimiter=',')

# Extract x and y values from the data
x_values = data1[:, 1]
y_values = data1[:, 2]

# Plot data using Matplotlib
plt.plot(x_values, y_values)
plt.xlabel('Epochs')
plt.ylabel('Acurracy')
plt.title('Accuracy During Training')
plt.show()

# Save the plot as an EPS file
plt.savefig('/content/drive/MyDrive/EPS/Accuracy During Training.eps', format='eps')

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import io
import os

# Replace with the ID of the folder in your Google Drive where you want to save the file
folder_id = '1ZJdCIUB5VwsrjqfKUbgtfcFsBpzY7gO8'

# Replace with the path to the EPS file you want to upload
eps_file_path = '/content/drive/MyDrive/EPS/Accuracy During Training.eps'

# Create a Google Drive API client
#service = build('drive', 'v3', credentials=creds)

# Upload the file to Google Drive
file_metadata = {'name': os.path.basename(eps_file_path), 'parents':[folder_id]}
media = io.FileIO(eps_file_path, 'rb')
file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()
print(f'File ID: {file.get("id")}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-380d7c5e2183> in <module>
#      15 # Upload the file to Google Drive
#      16 file_metadata = {'name': os.path.basename(eps_file_path), 'parents':[folder_id]}
# ---> 17 media = io.FileIO(eps_file_path, 'rb')
#      18 file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()
#      19 print(f'File ID: {file.get("id")}')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/EPS/Accuracy During Training.eps'

# %%
# Load the CSV file using NumPy
data2 = np.loadtxt(path2, delimiter=',')

# Extract x and y values from the data
x_values = data2[:, 1]
y_values = data2[:, 2]

# Plot data using Matplotlib
plt.plot(x_values, y_values)
plt.xlabel('Epochs')
plt.ylabel('Acurracy')
plt.title('Accuracy During Validation')
plt.show()

# %%
# Load the CSV file using NumPy
data3 = np.loadtxt(path3, delimiter=',')

# Extract x and y values from the data
x_values = data3[:, 1]
y_values = data3[:, 2]

# Plot data using Matplotlib
plt.plot(x_values, y_values)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss During Training')
plt.show()

# %%
# Load the CSV file using NumPy
data4 = np.loadtxt(path4, delimiter=',')

# Extract x and y values from the data
x_values = data4[:, 1]
y_values = data4[:, 2]

# Plot data using Matplotlib
plt.plot(x_values, y_values)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss During Validation')
plt.show()
